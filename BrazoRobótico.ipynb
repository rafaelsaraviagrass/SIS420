# %%
import sys, os
import importlib.metadata

# Ajusta esta ruta si tu carpeta no se llama exactamente bullet3-3.25
sys.path.append(os.path.abspath("bullet3-3.25"))

import pybullet as p
import pybullet_data
import gymnasium as gym
import numpy as np
import torch

# Mostrar versiones para confirmar instalación
print("✅ PyBullet", importlib.metadata.version("pybullet"))
print("✅ Gymnasium", gym.__version__)
print("✅ Torch", torch.__version__)
# Out:
# ✅ PyBullet 3.2.7
# ✅ Gymnasium 1.1.1
# ✅ Torch 2.5.1+cu121

# %%
from gymnasium import spaces

class RobotCupEnv(gym.Env):
    """Brazo Panda que voltea un vaso cilíndrico (reward = tilt − step_penalty)."""
    metadata = {"render_modes": ["human", "direct"], "render_fps": 240}

    def __init__(self, render_mode="direct"):
        super().__init__()
        self.render_mode = render_mode
        self.client = p.connect(p.GUI if render_mode=="human" else p.DIRECT)

        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        self.time_step = 1/240
        p.setTimeStep(self.time_step, physicsClientId=self.client)
        p.setGravity(0,0,-9.8, physicsClientId=self.client)

        # acciona 7 juntas
        self.action_space = spaces.Box(
            low=np.array([-2.9]*7, dtype=np.float32),
            high=np.array([ 2.9]*7, dtype=np.float32),
        )
        low  = np.array([-3.2]*7 + [-1.0, -1.0, 0.0], dtype=np.float32)
        high = np.array([ 3.2]*7 + [ 1.0,  1.0, 1.0], dtype=np.float32)
        self.observation_space = spaces.Box(low, high, dtype=np.float32)

        self.max_steps   = 240*5
        self.step_counter = 0

    def reset(self, *, seed=None, options=None):
        p.resetSimulation(physicsClientId=self.client)
        p.setGravity(0,0,-9.8, physicsClientId=self.client)
        p.setTimeStep(self.time_step, physicsClientId=self.client)
        p.loadURDF("plane.urdf", physicsClientId=self.client)

        self.robot_id = p.loadURDF(
            "franka_panda/panda.urdf",
            basePosition=[0,0,0],
            useFixedBase=True,
            physicsClientId=self.client
        )
        col = p.createCollisionShape(p.GEOM_CYLINDER, radius=0.03, height=0.1,
                                     physicsClientId=self.client)
        vis = p.createVisualShape(p.GEOM_CYLINDER, radius=0.03, length=0.1,
                                  rgbaColor=[1,1,1,1],
                                  physicsClientId=self.client)
        x = self.np_random.uniform(-0.3, 0.3)  # rango más pequeño para facilitar
        self.cup_id = p.createMultiBody(
            baseMass=0.1,
            baseCollisionShapeIndex=col,
            baseVisualShapeIndex=vis,
            basePosition=[x,0,0.05],
            physicsClientId=self.client
        )

        self.step_counter = 0
        return self._get_obs(), {}

    def step(self, action):
        for i, tgt in enumerate(action):
            p.setJointMotorControl2(
                self.robot_id, jointIndex=i,
                controlMode=p.POSITION_CONTROL,
                targetPosition=tgt,
                physicsClientId=self.client
            )
        p.stepSimulation(physicsClientId=self.client)
        self.step_counter += 1

        obs    = self._get_obs()
        reward = self._compute_reward()
        done   = self.step_counter >= self.max_steps
        term   = done or (reward >= 0.99)  # tilt casi 90°
        return obs, reward, term, False, {}

    def _get_obs(self):
        js     = p.getJointStates(self.robot_id, list(range(7)),
                                  physicsClientId=self.client)
        angles = [s[0] for s in js]
        pos,_  = p.getBasePositionAndOrientation(self.cup_id,
                                                  physicsClientId=self.client)
        return np.array(angles + list(pos), dtype=np.float32)

    def _compute_reward(self):
        _, quat = p.getBasePositionAndOrientation(self.cup_id,
                                                  physicsClientId=self.client)
        roll, pitch, _ = p.getEulerFromQuaternion(quat)
        tilt = max(abs(roll), abs(pitch))
        r_tilt = np.clip(tilt/(np.pi/2), 0, 1)
        # penalización por paso
        return float(r_tilt - 0.002)

    def render(self): pass
    def close(self): p.disconnect(physicsClientId=self.client)

# %%
env = RobotCupEnv(render_mode="direct")
obs, _ = env.reset()
for _ in range(200):
    action = env.action_space.sample()
    obs, reward, term, trunc, info = env.step(action)
    if term or trunc:
        break
env.close()
print("✅ Test direct finalizado | Reward:", reward)
# Out:
# ✅ Test direct finalizado | Reward: -0.0018926094014711011

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor

# 4 entornos en paralelo en modo DIRECT
venv = DummyVecEnv([lambda: RobotCupEnv(render_mode="direct") for _ in range(4)])
venv = VecMonitor(venv)   # sólo para registrar ep_len_mean y ep_rew_mean

model = PPO(
    "MlpPolicy",
    venv,
    verbose=1,
    device="cpu",
    n_steps=256,
    learning_rate=1e-4,
    ent_coef=0.05,
    batch_size=64,
)

model.learn(total_timesteps=500_000)
model.save("ppo_robot_cup_no_norm")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27       |
# |    ep_rew_mean     | 14.9     |
# | time/              |          |
# |    fps             | 668      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27           |
# |    ep_rew_mean          | 14.9         |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0043286807 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.94        |
# |    explained_variance   | 0.0285       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.508       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00532     |
# |    std                  | 1            |
# |    value_loss           | 0.998        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.010999614 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.97       |
# |    explained_variance   | -0.169      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.531      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0115      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014152285 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.99       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.52       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011727756 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.502      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 1.01        |
# |    value_loss           | 0.00151     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | 1.12         |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067386213 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10          |
# |    explained_variance   | 0.717        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.511       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 1.02         |
# |    value_loss           | 0.000944     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009422688 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.506      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 1.02        |
# |    value_loss           | 0.000609    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008269758 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.509      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1.02        |
# |    value_loss           | 0.000332    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.009522397 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.511      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1.02        |
# |    value_loss           | 0.000269    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 0.986       |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008410232 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.522      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 1.02        |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 0.986       |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.005935274 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.0149      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.214      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00325    |
# |    std                  | 1.03        |
# |    value_loss           | 0.779       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 0.986       |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 12          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010640863 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.535      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 1.03        |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 0.986       |
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 13          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.008454383 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.545      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1.03        |
# |    value_loss           | 0.00314     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 0.986       |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008395832 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.521      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 1.03        |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 967          |
# |    ep_rew_mean          | 1.04         |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 15           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0089587895 |
# |    clip_fraction        | 0.077        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.551       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 1.04         |
# |    value_loss           | 0.000994     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 967          |
# |    ep_rew_mean          | 1.04         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0058330745 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.2        |
# |    explained_variance   | -0.0292      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.209       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00681     |
# |    std                  | 1.04         |
# |    value_loss           | 0.929        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.012110843 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | -0.319      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.55       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010347887 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.52       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 1.05        |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 966         |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 19          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009922173 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.528      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 1.05        |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.7          |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 20           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0070291623 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.3        |
# |    explained_variance   | 0.00421      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.182        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00776     |
# |    std                  | 1.05         |
# |    value_loss           | 0.983        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.7         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 21          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.010770771 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -0.13       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.386      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1.05        |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.7         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 22          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009201547 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -1.85       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.549      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 1.06        |
# |    value_loss           | 0.00603     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.7          |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 23           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0078772865 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.3        |
# |    explained_variance   | -0.958       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.53        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 1.06         |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 2.55        |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 24          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007255098 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | -0.803      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.526      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1.06        |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 2.55        |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 25          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.004079477 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | -0.015      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.909       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00484    |
# |    std                  | 1.07        |
# |    value_loss           | 2.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 2.55        |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 26          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013741447 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.0686      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.534      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 1.07        |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 2.55        |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 27          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.010397774 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.55       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 1.08        |
# |    value_loss           | 0.00562     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 2.55        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 28          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007953368 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.553      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.08        |
# |    value_loss           | 0.00239     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 837          |
# |    ep_rew_mean          | 3.03         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 29           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0076814773 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.545       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00876     |
# |    std                  | 1.08         |
# |    value_loss           | 0.00184      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 819         |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 30          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006220598 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.00887     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.242       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00578    |
# |    std                  | 1.09        |
# |    value_loss           | 2.25        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | 3.69         |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 31           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0068461476 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | 0.016        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.276       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00943     |
# |    std                  | 1.09         |
# |    value_loss           | 1.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 819         |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 32          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011254689 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -1.19       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.56       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 1.1         |
# |    value_loss           | 0.0354      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 819         |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 33          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.009160337 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.567      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 1.1         |
# |    value_loss           | 0.00747     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 837         |
# |    ep_rew_mean          | 3.42        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 34          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009475918 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.545      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 1.11        |
# |    value_loss           | 0.00381     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 4.2          |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 35           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0048641963 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.7        |
# |    explained_variance   | 0.0456       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.197       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00487     |
# |    std                  | 1.12         |
# |    value_loss           | 0.767        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 4.2          |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 36           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0070054755 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.7        |
# |    explained_variance   | -0.052       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.711        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00841     |
# |    std                  | 1.12         |
# |    value_loss           | 2.25         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 803         |
# |    ep_rew_mean          | 4.2         |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 37          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.012816046 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | -0.72       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.528      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 1.13        |
# |    value_loss           | 0.0566      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | 3.91        |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 38          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010541173 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.548      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 1.13        |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 3.85         |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 39           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0063803764 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | -0.189       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.541       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0072      |
# |    std                  | 1.14         |
# |    value_loss           | 0.0184       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 40          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006854808 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.0135      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.475      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0092     |
# |    std                  | 1.14        |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 41          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.007511439 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.00919     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.333       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00874    |
# |    std                  | 1.14        |
# |    value_loss           | 1.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 4.05        |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 42          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010186443 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | -1.38       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.574      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 1.15        |
# |    value_loss           | 0.0219      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 822         |
# |    ep_rew_mean          | 3.8         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 43          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009074425 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | -1.3        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.576      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 1.15        |
# |    value_loss           | 0.00952     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 829          |
# |    ep_rew_mean          | 3.68         |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 44           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0064774905 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | -0.379       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.578       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0109      |
# |    std                  | 1.16         |
# |    value_loss           | 0.0097       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | 3.57        |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 45          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.008052692 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.118      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.553      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1.16        |
# |    value_loss           | 0.00379     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 836        |
# |    ep_rew_mean          | 3.57       |
# | time/                   |            |
# |    fps                  | 590        |
# |    iterations           | 46         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00766634 |
# |    clip_fraction        | 0.0627     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | -0.258     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.579     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0122    |
# |    std                  | 1.16       |
# |    value_loss           | 0.00313    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | 3.57        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 47          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.009948184 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -0.0811     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.565      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.17        |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | 3.77        |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 48          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008891435 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.569      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 1.17        |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | 3.77        |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 49          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.007294548 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.00307     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.459       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00792    |
# |    std                  | 1.17        |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | 3.67        |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 50          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009551454 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.467      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 1.18        |
# |    value_loss           | 0.127       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | 3.67        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 51          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.008634133 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.539      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00842    |
# |    std                  | 1.19        |
# |    value_loss           | 0.0931      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | 3.67        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 52          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010143295 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.563      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 1.19        |
# |    value_loss           | 0.00861     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | 3.55        |
# | time/                   |             |
# |    fps                  | 591         |
# ...
# |    std                  | 5.88          |
# |    value_loss           | 1.71          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | 7.11         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 473          |
# |    time_elapsed         | 905          |
# |    total_timesteps      | 484352       |
# | train/                  |              |
# |    approx_kl            | 0.0007669128 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.342       |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 5.89         |
# |    value_loss           | 1.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 768         |
# |    ep_rew_mean          | 7.1         |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 474         |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.002609048 |
# |    clip_fraction        | 0.00205     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.609      |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00457    |
# |    std                  | 5.9         |
# |    value_loss           | 1.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | 9.43         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 475          |
# |    time_elapsed         | 910          |
# |    total_timesteps      | 486400       |
# | train/                  |              |
# |    approx_kl            | 0.0051550474 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.655        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.275       |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.00678     |
# |    std                  | 5.91         |
# |    value_loss           | 1.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 756          |
# |    ep_rew_mean          | 9.59         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 476          |
# |    time_elapsed         | 912          |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0034567693 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.4        |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.61        |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00511     |
# |    std                  | 5.93         |
# |    value_loss           | 1.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 756          |
# |    ep_rew_mean          | 9.59         |
# | time/                   |              |
# |    fps                  | 534          |
# |    iterations           | 477          |
# |    time_elapsed         | 913          |
# |    total_timesteps      | 488448       |
# | train/                  |              |
# |    approx_kl            | 0.0037785242 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.4        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.896       |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.00431     |
# |    std                  | 5.96         |
# |    value_loss           | 0.487        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 766         |
# |    ep_rew_mean          | 9.33        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 478         |
# |    time_elapsed         | 915         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.005052315 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.09       |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00475    |
# |    std                  | 5.98        |
# |    value_loss           | 0.0608      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 766         |
# |    ep_rew_mean          | 9.34        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 479         |
# |    time_elapsed         | 918         |
# |    total_timesteps      | 490496      |
# | train/                  |             |
# |    approx_kl            | 0.008071399 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.11       |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00886    |
# |    std                  | 6.02        |
# |    value_loss           | 0.0979      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 786        |
# |    ep_rew_mean          | 8.83       |
# | time/                   |            |
# |    fps                  | 534        |
# |    iterations           | 480        |
# |    time_elapsed         | 920        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.00705552 |
# |    clip_fraction        | 0.0285     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.5      |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.11      |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.00727   |
# |    std                  | 6.05       |
# |    value_loss           | 0.125      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 786         |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 481         |
# |    time_elapsed         | 921         |
# |    total_timesteps      | 492544      |
# | train/                  |             |
# |    approx_kl            | 0.005282482 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.12       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 6.07        |
# |    value_loss           | 0.0287      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 786           |
# |    ep_rew_mean          | 8.91          |
# | time/                   |               |
# |    fps                  | 534           |
# |    iterations           | 482           |
# |    time_elapsed         | 923           |
# |    total_timesteps      | 493568        |
# | train/                  |               |
# |    approx_kl            | 0.00052002276 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -22.5         |
# |    explained_variance   | 0.361         |
# |    learning_rate        | 0.0001        |
# |    loss                 | -0.892        |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.000793     |
# |    std                  | 6.09          |
# |    value_loss           | 0.958         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 798         |
# |    ep_rew_mean          | 8.72        |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 483         |
# |    time_elapsed         | 925         |
# |    total_timesteps      | 494592      |
# | train/                  |             |
# |    approx_kl            | 0.008832924 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.15       |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00848    |
# |    std                  | 6.12        |
# |    value_loss           | 0.00832     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 778         |
# |    ep_rew_mean          | 9.05        |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 484         |
# |    time_elapsed         | 928         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.009557785 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.13       |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00983    |
# |    std                  | 6.16        |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 788         |
# |    ep_rew_mean          | 8.8         |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 485         |
# |    time_elapsed         | 931         |
# |    total_timesteps      | 496640      |
# | train/                  |             |
# |    approx_kl            | 0.002581701 |
# |    clip_fraction        | 0.00127     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.6       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.956      |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 6.18        |
# |    value_loss           | 0.299       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 788          |
# |    ep_rew_mean          | 8.8          |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 486          |
# |    time_elapsed         | 934          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0007325006 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.821       |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00143     |
# |    std                  | 6.19         |
# |    value_loss           | 0.888        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 788          |
# |    ep_rew_mean          | 8.8          |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 487          |
# |    time_elapsed         | 936          |
# |    total_timesteps      | 498688       |
# | train/                  |              |
# |    approx_kl            | 0.0055334517 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.14        |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00635     |
# |    std                  | 6.21         |
# |    value_loss           | 0.0391       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 788          |
# |    ep_rew_mean          | 8.79         |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 488          |
# |    time_elapsed         | 939          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0042478605 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.7        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.15        |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00416     |
# |    std                  | 6.24         |
# |    value_loss           | 0.0238       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 798        |
# |    ep_rew_mean          | 8.55       |
# | time/                   |            |
# |    fps                  | 532        |
# |    iterations           | 489        |
# |    time_elapsed         | 941        |
# |    total_timesteps      | 500736     |
# | train/                  |            |
# |    approx_kl            | 0.00487627 |
# |    clip_fraction        | 0.0101     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -22.7      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -1.13      |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.00434   |
# |    std                  | 6.26       |
# |    value_loss           | 0.0376     |
# ----------------------------------------

# %%
# Evaluación sin normalización
from stable_baselines3 import PPO

model = PPO.load("ppo_robot_cup_no_norm", device="cpu")
env   = RobotCupEnv(render_mode="human")

obs, _       = env.reset()
total_reward = 0.0

for _ in range(500):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, trunc, _ = env.step(action)
    total_reward += reward
    if done or trunc:
        break

# Tilt final
pos, quat = p.getBasePositionAndOrientation(env.cup_id, physicsClientId=env.client)
roll, pitch, _ = p.getEulerFromQuaternion(quat)

env.close()
print(f"🎯 Recompensa acumulada: {total_reward:.3f}")
print(f"🔄 Tilt final → roll: {roll:.2f} rad, pitch: {pitch:.2f} rad")
# Out:
# 🎯 Recompensa acumulada: 14.565
# 🔄 Tilt final → roll: -1.57 rad, pitch: 0.91 rad
